# %% [markdown]
# # Bootstrap Acme FastAPI Service
#
# Use this notebook to validate your development environment and kick off automation routines.

# %% [markdown]
# ## Quick Start
#
# 1. Create a virtual environment and install dependencies.
# 2. Run the smoke tests to make sure everything is configured correctly.

# %%
# !python -m venv .venv
# !source .venv/bin/activate && pip install -e .[dev]
# !pytest -q
